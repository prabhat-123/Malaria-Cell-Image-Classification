# %%
# !pip install kaggle

# %%
# !mkdir kaggle

# %%
import json
token = {"username":"prabhatale","key":"a17630a4aed5ea80bd008176986b2036"}
with open('/content/kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !cp /content/kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content}
# Out:
# ...
# - path is now set to: {/content}

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d iarunava/cell-images-for-detecting-malaria -p /content
# Out:
# ...
#  97% 657M/675M [00:17<00:00, 35.2MB/s]
# 100% 675M/675M [00:18<00:00, 39.2MB/s]

# %%
import zipfile
archive = zipfile.ZipFile('/content/cell-images-for-detecting-malaria.zip')
archive.extractall('/content')

# %%
parasitized_folder = '/content/cell_images/Parasitized'
uninfected_folder = '/content/cell_images/Uninfected'
cell_images_folder = '/content/cell_images/cell_images'

# %%
import os
for folders in os.listdir(cell_images_folder):
  print("There are {} images in {} folder.".format(len(os.listdir(os.path.join(cell_images_folder,folders))),folders))
# Out:
# There are 13780 images in Parasitized folder.
# There are 13780 images in Uninfected folder.

# %%
os.mkdir('/content/Malaria_cell_images')
os.mkdir('/content/Malaria_cell_images/train')
os.mkdir('/content/Malaria_cell_images/valid')
os.mkdir('/content/Malaria_cell_images/test')

# %%
os.mkdir('/content/Malaria_cell_images/train/Parasitized')
os.mkdir('/content/Malaria_cell_images/valid/Parasitized')
os.mkdir('/content/Malaria_cell_images/test/Parasitized')
os.mkdir('/content/Malaria_cell_images/train/Uninfected')
os.mkdir('/content/Malaria_cell_images/valid/Uninfected')
os.mkdir('/content/Malaria_cell_images/test/Uninfected')

# %%
import random
def select_random_generator_images(generator_dir,no_of_samples):
  selected_samples = []
  generator_dir = generator_dir
  selection = random.sample(os.listdir(generator_dir),no_of_samples)
  for choices in selection:
    choice = os.path.join(generator_dir,choices)
    selected_samples.append(choice)
  return selected_samples

# %%
training_parasitized_image_path = select_random_generator_images(parasitized_folder,8268)
print(training_parasitized_image_path)
print(len(training_parasitized_image_path))
# Out:
# ['/content/cell_images/Parasitized/C128P89ThinF_IMG_20151004_131632_cell_171.png', '/content/cell_images/Parasitized/C131P92ThinF_IMG_20151004_145410_cell_134.png', '/content/cell_images/Parasitized/C48P9thinF_IMG_20150721_160406_cell_234.png', '/content/cell_images/Parasitized/C110P71ThinF_IMG_20150930_105925_cell_219.png', '/content/cell_images/Parasitized/C97P58ThinF_IMG_20150917_145555_cell_166.png', '/content/cell_images/Parasitized/C142P103ThinF_IMG_20151005_221931_cell_189.png', '/content/cell_images/Parasitized/C80P41ThinF_IMG_20150817_111943_cell_2.png', '/content/cell_images/Parasitized/C128P89ThinF_IMG_20151004_130549_cell_144.png', '/content/cell_images/Parasitized/C129P90ThinF_IMG_20151004_133703_cell_94.png', '/content/cell_images/Parasitized/C101P62ThinF_IMG_20150918_151335_cell_58.png', '/content/cell_images/Parasitized/C116P77ThinF_IMG_20150930_171844_cell_88.png', '/content/cell_images/Parasitized/C49P10thinF_IMG_20150724_103233_cell_196.png', '/content/cell_images/
# ...

# %%
import shutil
for path in training_parasitized_image_path:
  shutil.move(path,'/content/Malaria_cell_images/train/Parasitized')

# %%
print(len(os.listdir('/content/Malaria_cell_images/train/Parasitized')))
# Out:
# 8268

# %%
print(len(os.listdir('/content/cell_images/Parasitized')))
# Out:
# 5512

# %%
valid_parasitized_image_path = select_random_generator_images(parasitized_folder,2756)
print(valid_parasitized_image_path)
print(len(valid_parasitized_image_path))
# Out:
# ['/content/cell_images/Parasitized/C124P85ThinF_IMG_20151002_154808_cell_140.png', '/content/cell_images/Parasitized/C45P6ThinF_IMG_20151130_160409_cell_189.png', '/content/cell_images/Parasitized/C175P136NThinF_IMG_20151127_141428_cell_226.png', '/content/cell_images/Parasitized/C132P93ThinF_IMG_20151004_151701_cell_144.png', '/content/cell_images/Parasitized/C182P143NThinF_IMG_20151201_172257_cell_174.png', '/content/cell_images/Parasitized/C182P143NThinF_IMG_20151201_171950_cell_182.png', '/content/cell_images/Parasitized/C70P31_ThinF_IMG_20150819_142744_cell_88.png', '/content/cell_images/Parasitized/C137P98ThinF_IMG_20151005_161859_cell_83.png', '/content/cell_images/Parasitized/C97P58ThinF_IMG_20150917_151320_cell_154.png', '/content/cell_images/Parasitized/C179P140ThinF_IMG_20151127_153819_cell_176.png', '/content/cell_images/Parasitized/C183P144NThinF_IMG_20151201_222917_cell_148.png', '/content/cell_images/Parasitized/C137P98ThinF_IMG_20151005_164119_cell_80.png', '/content/
# ...

# %%
for path in valid_parasitized_image_path:
  shutil.move(path,'/content/Malaria_cell_images/valid/Parasitized')

# %%
print(len(os.listdir('/content/Malaria_cell_images/valid/Parasitized')))
# Out:
# 2756

# %%
print(len(os.listdir('/content/cell_images/Parasitized')))
# Out:
# 2756

# %%
test_parasitized_image_path = select_random_generator_images(parasitized_folder,2756)
print(test_parasitized_image_path)
print(len(test_parasitized_image_path))
# Out:
# ['/content/cell_images/Parasitized/C92P53ThinF_IMG_20150821_151722_cell_224.png', '/content/cell_images/Parasitized/C60P21thinF_IMG_20150804_105639_cell_10.png', '/content/cell_images/Parasitized/C116P77ThinF_IMG_20150930_171739_cell_81.png', '/content/cell_images/Parasitized/C180P141NThinF_IMG_20151201_170110_cell_13.png', '/content/cell_images/Parasitized/C74P35_ThinF_IMG_20150815_114555_cell_130.png', '/content/cell_images/Parasitized/C101P62ThinF_IMG_20150923_170110_cell_24.png', '/content/cell_images/Parasitized/C102P63ThinF_IMG_20150918_162051_cell_141.png', '/content/cell_images/Parasitized/C133P94ThinF_IMG_20151004_154919_cell_128.png', '/content/cell_images/Parasitized/C39P4thinF_original_IMG_20150622_111942_cell_5.png', '/content/cell_images/Parasitized/C174P135NThinF_IMG_20151127_135706_cell_1.png', '/content/cell_images/Parasitized/C59P20thinF_IMG_20150803_111244_cell_173.png', '/content/cell_images/Parasitized/C184P145ThinF_IMG_20151203_103824_cell_125.png', '/content/ce
# ...

# %%
for path in test_parasitized_image_path:
  shutil.move(path,'/content/Malaria_cell_images/test/Parasitized')

# %%
print(len(os.listdir('/content/Malaria_cell_images/test/Parasitized')))
# Out:
# 2756

# %%
print(len(os.listdir('/content/cell_images/Parasitized')))
# Out:
# 0

# %%
training_uninfected_image_path = select_random_generator_images(uninfected_folder,8268)
print(training_uninfected_image_path)
print(len(training_uninfected_image_path))
# Out:
# ['/content/cell_images/Uninfected/C188P149ThinF_IMG_20151203_134449_cell_42.png', '/content/cell_images/Uninfected/C61P22N_ThinF_IMG_20150818_112518_cell_156.png', '/content/cell_images/Uninfected/C33P1thinF_IMG_20150619_114756a_cell_157.png', '/content/cell_images/Uninfected/C52P13thinF_IMG_20150725_123938_cell_171.png', '/content/cell_images/Uninfected/C68P29N_ThinF_IMG_20150819_134112_cell_99.png', '/content/cell_images/Uninfected/C46P7ThinF_IMG_20151130_210309_cell_18.png', '/content/cell_images/Uninfected/C99P60ThinF_IMG_20150918_141001_cell_60.png', '/content/cell_images/Uninfected/C51AP12thinF_IMG_20150724_155947_cell_82.png', '/content/cell_images/Uninfected/C121P82ThinF_IMG_20151002_133540_cell_14.png', '/content/cell_images/Uninfected/C6NThinF_IMG_20150609_122421_cell_106.png', '/content/cell_images/Uninfected/C141P102ThinF_IMG_20151005_214338_cell_119.png', '/content/cell_images/Uninfected/C172P133ThinF_IMG_20151119_155343_cell_74.png', '/content/cell_images/Uninfected/C18
# ...

# %%
for path in training_uninfected_image_path:
  shutil.move(path,'/content/Malaria_cell_images/train/Uninfected')

# %%
print(len(os.listdir('/content/Malaria_cell_images/train/Uninfected')))
# Out:
# 8268

# %%
print(len(os.listdir('/content/cell_images/Uninfected')))
# Out:
# 5512

# %%
valid_uninfected_image_path = select_random_generator_images(uninfected_folder,2756)
print(valid_uninfected_image_path)
print(len(valid_uninfected_image_path))
# Out:
# ['/content/cell_images/Uninfected/C80P41ThinF_IMG_20150817_110834_cell_91.png', '/content/cell_images/Uninfected/C58P19thinF_IMG_20150802_123134_cell_172.png', '/content/cell_images/Uninfected/C73P34_ThinF_IMG_20150815_111501_cell_119.png', '/content/cell_images/Uninfected/C104P65ThinF_IMG_20150918_171751_cell_106.png', '/content/cell_images/Uninfected/C136P97ThinF_IMG_20151005_140646_cell_82.png', '/content/cell_images/Uninfected/C114P75ThinF_IMG_20150930_150733_cell_5.png', '/content/cell_images/Uninfected/C56P17thinF_IMG_20150728_155921_cell_12.png', '/content/cell_images/Uninfected/C226ThinF_IMG_20151112_131622_cell_22.png', '/content/cell_images/Uninfected/C132P93ThinF_IMG_20151004_151733_cell_59.png', '/content/cell_images/Uninfected/C173P134NThinF_IMG_20151130_120046_cell_150.png', '/content/cell_images/Uninfected/C225ThinF_IMG_20151112_113735_cell_8.png', '/content/cell_images/Uninfected/C92P53ThinF_IMG_20150821_150457_cell_97.png', '/content/cell_images/Uninfected/C13NThinF_
# ...

# %%
for path in valid_uninfected_image_path:
  shutil.move(path,'/content/Malaria_cell_images/valid/Uninfected')

# %%
print(len(os.listdir('/content/Malaria_cell_images/valid/Uninfected')))
# Out:
# 2756

# %%
print(len(os.listdir('/content/cell_images/Uninfected')))
# Out:
# 2756

# %%
test_uninfected_image_path = select_random_generator_images(uninfected_folder,2756)
print(len(test_uninfected_image_path))
print(test_uninfected_image_path)
# Out:
# 2756
# ...

# %%
for path in test_uninfected_image_path:
  shutil.move(path,'/content/Malaria_cell_images/test/Uninfected')

# %%
print(len(os.listdir('/content/Malaria_cell_images/test/Uninfected')))
# Out:
# 2756

# %%
print(len(os.listdir('/content/cell_images/Uninfected')))
# Out:
# 0

# %%
# !rm -rf "/content/cell_images"

# %%
train_dir = '/content/Malaria_cell_images/train'
test_dir = '/content/Malaria_cell_images/test'
valid_dir = '/content/Malaria_cell_images/valid'

# %%
# visualization
category = ['Parasitized','Uninfected']

# %%
def get_images(data_dir,samples):
  training_images_path = []
  for cell_type in category:
    path = os.path.join(data_dir,cell_type)
    i = 0
    for img in os.listdir(path):
      i+= 1
      if i > samples:
        break
      else:
        training_images_path.append(os.path.join(path,img))
  return training_images_path

# %%
import matplotlib.pyplot as plt
import cv2
def visualize_cells(images_path,rows,cols):
  fig = plt.figure(figsize=(20,20))
  rows = rows
  cols = cols
  for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_array = cv2.imread(images_path[i-1])
    fig.subplots_adjust(hspace=1)
    plt.imshow(cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB))
    plt.xlabel(images_path[i-1].split('/')[-2])
  plt.show()

# %%
train_images_path = get_images(train_dir,10)
valid_images_path = get_images(valid_dir,10)
test_images_path = get_images(test_dir,10)

# %%
visualize_cells(train_images_path,4,5)

# %%
visualize_cells(valid_images_path,4,5)

# %%
visualize_cells(test_images_path,4,5)

# %%
from keras.applications.resnet import ResNet50
from keras.layers import Dense,Dropout,Flatten
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau,EarlyStopping,ModelCheckpoint

# %%
train_datagen = ImageDataGenerator(rescale=1./255,rotation_range=0.2,horizontal_flip=True,vertical_flip=True,shear_range=0.2,brightness_range=(0.4,1.4),zca_whitening=True)
valid_datagen = ImageDataGenerator(rescale=1./255)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:337: UserWarning: This ImageDataGenerator specifies `zca_whitening`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
train_generator = train_datagen.flow_from_directory(train_dir,target_size=(224,224),color_mode='rgb',
                                                    class_mode='binary',batch_size=25,shuffle=True)
# Out:
# Found 16536 images belonging to 2 classes.

# %%
valid_generator = valid_datagen.flow_from_directory(valid_dir,target_size=(224,224),color_mode='rgb',
                                                    class_mode='binary',batch_size=25)
# Out:
# Found 5511 images belonging to 2 classes.

# %%
resnet = ResNet50(weights='imagenet',include_top=False,input_shape=(224,224,3))

# %%
resnet.trainable = False

# %%
# # Let's take a look to see how many layers are in the base model
# print("Number of layers in the base model: ", len(resnet.layers))

# # Fine-tune from this layer onwards
# fine_tune_at = 170

# # Freeze all the layers before the `fine_tune_at` layer
# for layer in resnet.layers[:fine_tune_at]:
#   layer.trainable =  False

# %%
output = Flatten()(resnet.output)
prediction = Dense(1,activation='sigmoid')(output)

# %%
model = Model(inputs = resnet.input,outputs = prediction)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='binary_crossentropy',
  optimizer=Adam(
    learning_rate=0.000001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07
),
  metrics=['accuracy']
)

# %%
import os
os.mkdir('/content/model_weights/')

# %%
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
model_checkpoint = ModelCheckpoint('./model_weights/flowers_model_{epoch:02d}-{val_accuracy:.6f}.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True,save_weights_only=True)

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=10, min_lr=0.0000000001, verbose=1,cooldown=0)

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // 25,
    validation_data = valid_generator, 
    validation_steps = valid_generator.samples // 25,
    epochs = 100,
    callbacks=[model_checkpoint,reduce_lr,early_stopping])
# Out:
# Epoch 1/100
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:739: UserWarning: This ImageDataGenerator specifies `zca_whitening`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 661/661 [==============================] - 388s 587ms/step - loss: 0.5433 - accuracy: 0.7491 - val_loss: 0.7445 - val_accuracy: 0.7255
#
# Epoch 00001: val_loss improved from inf to 0.74450, saving model to ./model_weights/flowers_model_01-0.725455.h5
# Epoch 2/100
# ...

# %%
import matplotlib.pyplot as plt
train_accuracy = history.history['accuracy'][:43]
validation_accuracy = history.history['val_accuracy'][:43]
epochs = range(1,44)
plt.plot(epochs,train_accuracy,'g',label='Train Accuracy')
plt.plot(epochs,validation_accuracy,'b',label='Validation Accuracy')
plt.title('Training Vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
train_loss = history.history['loss'][:43]
val_loss = history.history['val_loss'][:43]
epochs = range(1,44)
plt.plot(epochs,train_loss,'g', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
train_accuracy = history.history['accuracy'][:18]
validation_accuracy = history.history['val_accuracy'][:18]
epochs = range(1,19)
plt.plot(epochs,train_accuracy,'g',label='Train Accuracy')
plt.plot(epochs,validation_accuracy,'b',label='Validation Accuracy')
plt.title('Training Vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
train_loss = history.history['loss'][:18]
val_loss = history.history['val_loss'][:18]
epochs = range(1,19)
plt.plot(epochs,train_loss,'g', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import os
os.rename('/content/model_weights/flowers_model_18-0.956981.h5',"/content/model_weights/malaria_cell_classification_model_18-0.956981.h5")

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !cp -r "/content/model_weights/malaria_cell_classification_model_18-0.956981.h5" "/content/gdrive/My Drive"
# !cp -r "/content/malariacell_classification_model.json" "/content/gdrive/My Drive"

# %%
# serialize model to JSON
model_json = model.to_json()
with open("malariacell_classification_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
from keras.models import model_from_json
# load json and create model
json_file = open('/content/malariacell_classification_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("/content/model_weights/flowers_model_18-0.956981.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
from keras.preprocessing import image
import numpy as np
def check_flowers(path,cell_type):
  predictor = {}
  path= os.path.join(path,cell_type)
  for img in os.listdir(path):
    try:
      img = image.load_img(os.path.join(path,img),target_size=(224,224))
      img = image.img_to_array(img)
      img = np.expand_dims(img,axis=0)
      img = img / 255.0
      prediction = loaded_model.predict(img)
      if prediction > 0.5:
        prediction_class = 1
      else:
        prediction_class = 0
      result = category[prediction_class]
      if result not in predictor:
        predictor[result] = 1
      else:
        predictor[result] += 1
    except Exception as e:
      pass
  return predictor

# %%
check_flowers(test_dir,category[1])
# Out:
# {'Parasitized': 80, 'Uninfected': 2675}

# %%
category[0]
# Out:
# 'Parasitized'
